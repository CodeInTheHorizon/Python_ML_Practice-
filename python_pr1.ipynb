# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeInTheHorizon/Python_ML_Practice-/blob/main/python_pr1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data1 = [[1,2,3,4],[5,6,7,8]]

# %%
arr1 = np.array(data1)

# %%
data1.__class__
# Out:
# list

# %%
arr1.__class__
# Out:
# numpy.ndarray

# %%
arr1.ndim
# Out:
# 2

# %%
arr1.shape
# Out:
# (2, 4)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/time_series_forecasting/weather_data.csv")

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.head(10)
# Out:
#         Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1   2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2   2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3   2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4   2/5/2008     19.7     25.7      77.4          4.8       0.0           W
# 5   2/6/2008     20.2     27.2       1.6          2.6       8.6           W
# 6   2/7/2008     18.6     26.3       6.2          5.2       5.2           W
# 7   2/8/2008     17.2     22.3      27.6          5.8       2.1           W
# 8   2/9/2008     16.4     20.8      12.6          4.8       3.0           W
# 9  2/10/2008     14.6     24.2       8.8          4.4      10.1           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# ...

# %%
df.tail(10)
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 3261  6/16/2017     11.9     17.3       0.0          1.6       0.2
# 3262  6/17/2017     13.2     19.1       0.0          1.0       0.2
# 3263  6/18/2017     11.3     18.0       1.8          2.0       6.3
# 3264  6/19/2017     11.2     18.3       0.4          2.2       1.9
# 3265  6/20/2017     11.3     20.0       4.4          2.2       5.8
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 3261         WNW             26          W        WSW  ...           79
# 3262         SSW             26        WNW        SSW  ...           81
# ...

# %%
df['MinTemp'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Date              object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am       int64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.size
# Out:
# 71962

# %%
df.shape
# Out:
# (3271, 22)

# %%
len(df)
# Out:
# 3271

# %%
df.shape[0]
# Out:
# 3271

# %%
df.columns
# Out:
# Index(['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   MinTemp        3271 non-null   float64
#  2   MaxTemp        3271 non-null   float64
#  3   Rainfall       3271 non-null   float64
#  4   Evaporation    3271 non-null   float64
#  5   Sunshine       3271 non-null   float64
#  6   WindGustDir    3271 non-null   object
#  7   WindGustSpeed  3271 non-null   int64
#  8   WindDir9am     3271 non-null   object
#  9   WindDir3pm     3271 non-null   object
#  10  WindSpeed9am   3271 non-null   int64
#  11  WindSpeed3pm   3271 non-null   int64
#  12  Humidity9am    3271 non-null   int64
#  13  Humidity3pm    3271 non-null   int64
#  14  Pressure9am    3271 non-null   float64
#  15  Pressure3pm    3271 non-null   float64
#  16  Cloud9am       3271 non-null   int64
# ...

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     14.877102    23.005564     3.342158     5.175787     7.168970
# std       4.554710     4.483752     9.917746     2.757684     3.815966
# min       4.300000    11.700000     0.000000     0.000000     0.000000
# 25%      11.000000    19.600000     0.000000     3.200000     4.250000
# 50%      14.900000    22.800000     0.000000     4.800000     8.300000
# 75%      18.800000    26.000000     1.400000     7.000000    10.200000
# max      27.600000    45.800000   119.400000    18.400000    13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    3271.000000   3271.000000   3271.000000  3271.000000  3271.000000
# mean       41.476307     15.077041     19.294405    68.243962    54.698563
# std        10.806951      7.043825      7.453331    15.086127    16.279241
# ...

# %%
df.std(numeric_only=True)
# Out:
# MinTemp           4.554710
# MaxTemp           4.483752
# Rainfall          9.917746
# Evaporation       2.757684
# Sunshine          3.815966
# WindGustSpeed    10.806951
# WindSpeed9am      7.043825
# WindSpeed3pm      7.453331
# Humidity9am      15.086127
# Humidity3pm      16.279241
# Pressure9am       7.020090
# Pressure3pm       7.019915
# Cloud9am          2.526923
# Cloud3pm          2.411274
# Temp9am           4.894316
# Temp3pm           4.297053
# dtype: float64

# %%
df2= df.head(50)

# %%
df2.mean(numeric_only=True)
# Out:
# MinTemp            18.304
# MaxTemp            24.946
# Rainfall            5.652
# Evaporation         5.712
# Sunshine            7.226
# WindGustSpeed      41.000
# WindSpeed9am       11.760
# WindSpeed3pm       20.080
# Humidity9am        76.500
# Humidity3pm        63.460
# Pressure9am      1017.272
# Pressure3pm      1015.722
# Cloud9am            4.460
# Cloud3pm            4.240
# Temp9am            20.922
# Temp3pm            23.598
# dtype: float64

# %%
df.head(50).mean(numeric_only=True)
# Out:
# MinTemp            18.304
# MaxTemp            24.946
# Rainfall            5.652
# Evaporation         5.712
# Sunshine            7.226
# WindGustSpeed      41.000
# WindSpeed9am       11.760
# WindSpeed3pm       20.080
# Humidity9am        76.500
# Humidity3pm        63.460
# Pressure9am      1017.272
# Pressure3pm      1015.722
# Cloud9am            4.460
# Cloud3pm            4.240
# Temp9am            20.922
# Temp3pm            23.598
# dtype: float64

# %%
df['MinTemp'].mean()
# Out:
# np.float64(14.877101803729746)

# %%
df['MaxTemp'].describe()
# Out:
# count    3271.000000
# mean       23.005564
# std         4.483752
# min        11.700000
# 25%        19.600000
# 50%        22.800000
# 75%        26.000000
# max        45.800000
# Name: MaxTemp, dtype: float64

# %%
df['MaxTemp'].size
# Out:
# 3271

# %%
df['MaxTemp'].mean()
# Out:
# np.float64(23.00556404769184)
