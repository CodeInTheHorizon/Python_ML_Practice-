# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeInTheHorizon/Python_ML_Practice-/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OOPs**
# - *a class has attributes and behaviour*

# %% [markdown]
# **creatng classes**
# - *its a blueprint to create objects*
# - *the class keyword is used to create classes*
# - *by general convetion we start name with capital leter*
# - **example: int,float,string, etc.**

# %%
class Car:
  pass

# %% [markdown]
# **Objects**
# - *objects are instances or enitities of a class.*
# - *it has all the properties of its class*
# - *eg: 1,2 are objects of int class*

# %%
honda =Car()

# %%
type(honda)
# Out:
# __main__.Car

# %%
type(1)
# Out:
# int

# %%
type("kshitij")
# Out:
# str

# %% [markdown]
# **Constructor**
# - *A constructor is a special method used to create and initialise an object of a class*
# - *This method is defined in the class*
# - *the constructor is executed autmaticlly at the time of object cvreation*

# %%
class Human:
  # i want some properties to be with every human objects
  #double __
  def __init__(self,name,age,hobby):
    self.name=name
    self.age=age
    self.hobby=hobby

# %%
kshitij = Human("kshitij",21,"swimming")

# %%
print(kshitij)

# %%
emma = Human()
# Out:
# this will always print
